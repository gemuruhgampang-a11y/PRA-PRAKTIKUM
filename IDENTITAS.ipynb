# %% [markdown]
# <a href="https://colab.research.google.com/github/gemuruhgampang-a11y/PRA-PRAKTIKUM/blob/main/IDENTITAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Menyimpan data nama ke dalam nama
nama = "Gemuruh Gampang Anugrah"

#Menyimpan Nomor Induk Mahasiswa (NIM) ke dalam penelitian nim
nim = "2605060068"

#Menyimpan tempat dan tanggal lahir ke dalam variabel ttl
ttl = "Kebumen,30-05-2008"

#Menyimpan alamat tempat tinggal ke dalam alamat
alamat = "Kebumen,Petanahan, Jatimulyo, Jatisari,003/002"

#Menyimpan jenis kelamin ke dalam jenis kelamin
jenis_kelamin = "Laki-laki"

#Menyimpan hobi ke dalam hobi
hobi = "Running dan Bermain Game"

#Menampilkan judul
print("IDENTITAS")

#Menampilkan nama
print("Nama            :",nama)

#Menampilkan NIM
print("NIM             :",nim)

#Menampilkan tempat dan tanggal lahir
print("Tempat/Tgl Lahir:",ttl)

#Menampilkan alamat
print("Alamat          :",alamat)

#Menampilkan jenis kelamin
print("Jenis Kelamin   :",jenis_kelamin)

#Menampilkan hobi
print("Hobi            :",hobi)
# Out:
# IDENTITAS
# Nama            : Gemuruh Gampang Anugrah
# NIM             : 2605060068
# Tempat/Tgl Lahir: Kebumen,30-05-2008
# Alamat          : Kebumen,Petanahan, Jatimulyo, Jatisari,003/002
# Jenis Kelamin   : Laki-laki
# Hobi            : Running dan Bermain Game
